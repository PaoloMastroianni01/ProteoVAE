# %% [markdown]
# ## Import libraries

# %%
import scarches as sca
import numpy as np
import gdown
import scanpy as sc
import torch
import pandas as pd
# Out:
# WARNING:root:In order to use the mouse gastrulation seqFISH datsets, please install squidpy (see https://github.com/scverse/squidpy).
# c:\Users\utente\miniconda3\envs\scarches\lib\site-packages\docrep\decorators.py:43: SyntaxWarning: 'param_categorical_covariate_keys' is not a valid key!
#   doc = func(self, args[0].__doc__, *args[1:], **kwargs)
# c:\Users\utente\miniconda3\envs\scarches\lib\site-packages\docrep\decorators.py:43: SyntaxWarning: 'param_continuous_covariate_keys' is not a valid key!
#   doc = func(self, args[0].__doc__, *args[1:], **kwargs)
# WARNING:root:In order to use sagenet models, please install pytorch geometric (see https://pytorch-geometric.readthedocs.io) and
#  captum (see https://github.com/pytorch/captum).
# WARNING:root:mvTCR is not installed. To use mvTCR models, please install it first using "pip install mvtcr"
# WARNING:root:multigrate is not installed. To use multigrate models, please install it first using "pip install multigrate".

# %% [markdown]
# ## Load all datasets

# %%
proteo_data = pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/proteomics_wide_filtered_imputed_assay_82779.csv")

# %%
proteo_data.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)

# %%
proteo_data.head()
# Out:
#         ID   AARSD1  ABHD14B     ABL1    ACAA1    ACAN     ACE2    ACOX1  \
# 0  1000053  1.11265  0.62595  0.45535  0.24940  0.0519  0.70510  0.42815
# 1  1000096  0.38125  0.56845  0.98770  0.67755  0.4856 -0.09935 -0.40890
# 2  1000303  0.01830 -0.00280  0.23290  0.49820 -0.0496  0.14215 -0.00740
# 3  1000338 -0.88605 -0.78575 -1.54930 -0.03225 -0.2871  0.59375 -0.20590
# 4  1000346  0.00055 -0.49425 -0.39620 -0.85855 -0.3229  1.09325 -0.40390
#
#       ACP5     ACP6  ...   WNT9A    WWP2    XCL1       XG   XPNPEP2    XRCC4  \
# 0  0.31385 -1.14795  ... -0.4473  0.6136 -0.1398 -0.22765 -0.216250  0.22515
# 1  0.52110  0.00110  ...  0.0687  1.1570 -0.2341 -0.13710  1.124500 -0.01290
# 2  0.56370 -0.11720  ... -0.0299  0.6211  0.0490 -0.14200 -0.116164 -0.07995
# 3 -0.09250 -1.32490  ... -0.5619 -1.3833  0.2273 -0.93960 -2.204900 -0.19550
# 4  0.02950  0.27800  ... -0.0418 -0.5639 -0.3138 -0.68400 -0.740900  0.21530
#
#      YES1   YTHDF3   ZBTB16   ZBTB17
# ...

# %%
subjects_md = pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/subjects_metadata_82779.csv")

# %%
subjects_md
# Out:
#        Unnamed: 0    f.eid  Plate_used_for_sample  Batch
# 0               0  1000053           890000000592      7
# 1               1  1000096           890000000029      2
# 2               2  1000303           890000000147      3
# 3               3  1000338           890000000057      2
# 4               4  1000346           890000000030      2
# ...           ...      ...                    ...    ...
# 53060       53060  6023673           890000000305      4
# 53061       53061  6023837           890000000574      7
# 53062       53062  6024022           890000000444      5
# 53063       53063  6024045           890000000224      3
# 53064       53064  6024106           890000000107      3
#
# [53065 rows x 4 columns]

# %%
filtered_subjects_md = subjects_md[subjects_md['f.eid'].isin(proteo_data['ID'])]
filtered_subjects_md
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 filtered_subjects_md = subjects_md[subjects_md['f.eid'].isin(proteo_data.index)]
#       2 filtered_subjects_md
#
# NameError: name 'proteo_data' is not defined

# %%
proteins_md = pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/proteins_metadata.csv")

# %%
print(list(proteins_md.meaning.unique()))
# Out:
# ['Alpha-1B-glycoprotein', 'Mth938 domain-containing protein', 'Alanyl-tRNA editing protein Aarsd1', 'ATP-binding cassette sub-family A member 2', 'Protein ABHD14B', 'Tyrosine-protein kinase ABL1', 'Histo-blood group ABO system transferase', 'BRISC complex subunit Abraxas 2', '3-ketoacyl-CoA thiolase, peroxisomal', 'Medium-chain specific acyl-CoA dehydrogenase, mitochondrial', 'Short/branched chain specific acyl-CoA dehydrogenase, mitochondrial', 'Aggrecan core protein', 'Angiotensin-converting enzyme', 'Angiotensin-converting enzyme 2', 'Acetylcholinesterase', 'Acyl-coenzyme A thioesterase 13', 'Peroxisomal acyl-coenzyme A oxidase 1', 'Low molecular weight phosphotyrosine protein phosphatase', 'Tartrate-resistant acid phosphatase type 5', 'Lysophosphatidic acid phosphatase type 6', 'Acrosin-binding protein', 'Acrosomal protein SP-10', 'Long-chain-fatty-acid--CoA ligase 1', 'Actin, aortic smooth muscle', 'Alpha-actinin-2', 'Alpha-actinin-4', 'Serine/threonine-protein kinase receptor R
# ...

# %%
proteins_md.Panel.unique()
# Out:
# array(['Inflammation II', 'Cardiometabolic II', 'Oncology', 'Neurology',
#        'Oncology II', 'Cardiometabolic', 'Inflammation', 'Neurology II'],
#       dtype=object)

# %%
info_chd = pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/info_CHD_82779.csv")
# Out:
# C:\Users\utente\AppData\Local\Temp\ipykernel_23892\1573966378.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   info_chd = pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/info_CHD_82779.csv")

# %%
info_chd.head()
# Out:
#    Unnamed: 0       id  Age_at_recruitment  sex     YOB  MOB  \
# 0           1  1000015                64.0    0  1944.0  7.0
# 1           2  1000027                54.0    0  1954.0  2.0
# 2           3  1000039                46.0    1  1963.0  9.0
# 3           4  1000040                68.0    0  1941.0  3.0
# 4           5  1000053                58.0    1  1951.0  7.0
#
#    Etnic_group_visit_0  Etnic_group_visit_1  Etnic_group_visit_2  \
# 0               1001.0                  NaN                  NaN
# 1               1001.0                  NaN                  NaN
# 2               1001.0                  NaN                  NaN
# 3               1001.0                  NaN                  NaN
# 4               1001.0                  NaN                  NaN
#
#    Gen_ethnic_group  ... I25_source    I20    I21    I22    I23    I24    I25  \
# 0               NaN  ...        NaN  False  False  False  False  False  False
# ...

# %%
print(list(info_chd.columns))
# Out:
# ['Unnamed: 0', 'id', 'Age_at_recruitment', 'sex', 'YOB', 'MOB', 'Etnic_group_visit_0', 'Etnic_group_visit_1', 'Etnic_group_visit_2', 'Gen_ethnic_group', 'Date_of_death', 'Assessment_date', 'I20_date', 'I20_source', 'I21_date', 'I21_source', 'I22_date', 'I22_source', 'I23_date', 'I23_source', 'I24_date', 'I24_source', 'I25_date', 'I25_source', 'I20', 'I21', 'I22', 'I23', 'I24', 'I25', 'Total_CHD', 'Total_CHD_date', 'Prevalent']

# %%
info_sh = pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/info_SH_82779.csv")

# %%
info_sh.head()
# Out:
#    Unnamed: 0       id  Age_at_recruitment  sex     YOB  MOB  \
# 0           1  1000015                64.0    0  1944.0  7.0
# 1           2  1000027                54.0    0  1954.0  2.0
# 2           3  1000039                46.0    1  1963.0  9.0
# 3           4  1000040                68.0    0  1941.0  3.0
# 4           5  1000053                58.0    1  1951.0  7.0
#
#    Etnic_group_visit_0  Etnic_group_visit_1  Etnic_group_visit_2  \
# 0               1001.0                  NaN                  NaN
# 1               1001.0                  NaN                  NaN
# 2               1001.0                  NaN                  NaN
# 3               1001.0                  NaN                  NaN
# 4               1001.0                  NaN                  NaN
#
#    Gen_ethnic_group  ... I64_date I64_source I69_date  I69_source    I63  \
# 0               NaN  ...      NaN        NaN      NaN         NaN  False
# ...

# %%
print(list(info_sh.columns))
# Out:
# ['Unnamed: 0', 'id', 'Age_at_recruitment', 'sex', 'YOB', 'MOB', 'Etnic_group_visit_0', 'Etnic_group_visit_1', 'Etnic_group_visit_2', 'Gen_ethnic_group', 'Date_of_death', 'Assessment_date', 'I63_date', 'I63_source', 'I64_date', 'I64_source', 'I69_date', 'I69_source', 'I63', 'I64', 'I69', 'Total_SH', 'Total_SH_date', 'Prevalent']

# %%
diab= pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/complete_DIAB_analysis_82779_20240403.csv")
# Out:
# C:\Users\utente\AppData\Local\Temp\ipykernel_23892\1965110668.py:1: DtypeWarning: Columns (13,15,81,82) have mixed types. Specify dtype option on import or set low_memory=False.
#   diab= pd.read_csv("//storage.fht.org/healthds_exchange/ukb-ppp/complete_DIAB_analysis_82779_20240403.csv")

# %%
print(list(diab.columns))
# Out:
# ['Unnamed: 0', 'id', 'Age_at_recruitment', 'sex', 'YOB', 'MOB', 'Gen_ethnic_group', 'Date_of_death', 'Assessment_date', 'E10_date', 'E10_source', 'E11_date', 'E11_source', 'E12_date', 'E12_source', 'E13_date', 'E13_source', 'E14_date', 'E14_source', 'E10', 'E11', 'E12', 'E13', 'E14', 'Total_DIAB', 'Total_DIAB_date', 'Prevalent', 'UKB.PPP', 'BMI', 'Alcohol_drinker_status', 'Alcohol_intake_frequency', 'Smoking_status', 'Blood_type', 'Ethnic_background', 'HbA1c', 'HbA1c_follow_up', 'Assessment_date_follow_up', 'Pancreas_volume', 'Pancreas_PDFF', 'Abdominal_fat_ratio', 'Obesity_diag_prev', 'Hypertension_diag_prev', 'Physical_activity_days.week', 'Physical_activity_vigorous_days.week', 'genPC1', 'genPC2', 'genPC3', 'genPC4', 'genPC5', 'Body_fat_percentage', 'Whole_body_fat_mass', 'Deprivation_index', 'Hip_circumference', 'Type_II_Diab_E11_prev', 'Obesity_BMI_based', 'outcome_Type_II_Diab_diag', 'outcome_Type_II_Diab_HbA1c', 'outcome_Type_II_Diab_tot', 'use_antidiab_earliest_date', 'use_an
# ...

# %% [markdown]
# ## Filter dataset to keep only Cardiometabolic proteins

# %%
cm_proteins = list(proteins_md.get('gene_name')[(proteins_md.Panel == 'Cardiometabolic') | (proteins_md.Panel == "Cardiometabolic II")].unique())
print(cm_proteins)
# Out:
# ['AAMDC', 'ABCA2', 'ABRAXAS2', 'ACADSB', 'ACAN', 'ACE2', 'ACOX1', 'ACP5', 'ACSL1', 'ACTA2', 'ACTN2', 'ACY1', 'ACY3', 'ADA2', 'ADAM15', 'ADAMTS13', 'ADAMTS16', 'ADAMTSL2', 'ADAMTSL4', 'ADAMTSL5', 'ADGRE5', 'ADGRF5', 'ADGRG2', 'ADH4', 'ADRA2A', 'AGXT', 'AHCY', 'AHNAK', 'AHNAK2', 'AIF1L', 'AK1', 'AKR1C4', 'ALCAM', 'AMDHD2', 'AMY2A', 'AMY2B', 'ANG', 'ANGPTL1', 'ANGPTL3', 'ANK2', 'ANP32C', 'ANPEP', 'ANXA2', 'ANXA4', 'AOC3', 'APLP1', 'APOBR', 'APOM', 'ARL13B', 'ARL2BP', 'ARNTL', 'ART3', 'ASAH1', 'ASPN', 'ASRGL1', 'ASS1', 'ATP1B1', 'ATP1B2', 'ATP1B3', 'ATP2B4', 'ATP5F1D', 'ATP6V1G1', 'ATP6V1G2', 'AXL', 'AZU1', 'B3GAT3', 'B3GNT7', 'BAG6', 'BCAT1', 'BDNF', 'BECN1', 'BGLAP', 'BHMT2', 'BLMH', 'BMP6', 'BNIP2', 'BOC', 'BOLA2_BOLA2B', 'BPIFA2', 'BPIFB1', 'BPIFB2', 'BRD3', 'BRDT', 'C1GALT1C1', 'C1QTNF1', 'C2', 'CA1', 'CA13', 'CA3', 'CA4', 'CA5A', 'CACNA1H', 'CALCOCO2', 'CALY', 'CANT1', 'CASP3', 'CASQ2', 'CBLIF', 'CBS', 'CBX2', 'CCDC80', 'CCER2', 'CCL14', 'CCL15', 'CCL16', 'CCL18', 'CCL27', 'CCL5', 
# ...

# %%
proteo_data_cm = proteo_data[proteo_data.columns.intersection(cm_proteins)]

# %%
proteo_data_cm.head()
# Out:
#      ACAN     ACE2    ACOX1     ACP5    ACTA2     ACY1     ADA2   ADAM15  \
# 0  0.0519  0.70510  0.42815  0.31385 -0.04750  1.09255 -0.12875 -0.19330
# 1  0.4856 -0.09935 -0.40890  0.52110  0.47195  0.19125  0.27900  0.24195
# 2 -0.0496  0.14215 -0.00740  0.56370  1.54030 -0.22890  0.54330  0.53985
# 3 -0.2871  0.59375 -0.20590 -0.09250 -0.44775  0.44905 -0.75900 -0.21895
# 4 -0.3229  1.09325 -0.40390  0.02950  0.55455  0.34015  0.83870 -0.19885
#
#    ADAMTS13  ADAMTS16  ...    VAMP5     VASN    VCAM1      VIM     VSIR  \
# 0   0.14820   -0.4267  ... -0.27755 -0.32875 -0.06795 -0.73055  0.49345
# 1   0.25045    0.1565  ...  0.07950 -0.10630  0.13860  0.38770  0.88680
# 2  -0.24825   -0.0909  ... -0.16465 -0.14700  0.34310  0.98180  0.18860
# 3  -0.38645   -0.9002  ... -0.69630 -0.63620 -0.43960 -0.22120 -0.93110
# 4  -0.00345    0.2275  ... -0.02960 -0.29020  0.15250  0.77020 -0.82260
#
#     VSTM2L     VWF   WASF1       XG   ZBTB17
# 0 -0.57335  0.8550  1.1622 -0.22765  0.35215
# ...

# %%
print(list(proteo_data_cm.columns))
# Out:
# ['ACAN', 'ACE2', 'ACOX1', 'ACP5', 'ACTA2', 'ACY1', 'ADA2', 'ADAM15', 'ADAMTS13', 'ADAMTS16', 'ADGRE5', 'ADGRG2', 'ADH4', 'AGXT', 'AHCY', 'AK1', 'AKR1C4', 'ALCAM', 'AMY2A', 'AMY2B', 'ANG', 'ANGPTL1', 'ANGPTL3', 'ANPEP', 'ANXA4', 'AOC3', 'APLP1', 'APOM', 'ART3', 'AXL', 'AZU1', 'BAG6', 'BLMH', 'BMP6', 'BOC', 'BPIFB1', 'C1QTNF1', 'C2', 'CA1', 'CA13', 'CA3', 'CA4', 'CA5A', 'CANT1', 'CASP3', 'CBLIF', 'CCDC80', 'CCL14', 'CCL15', 'CCL16', 'CCL18', 'CCL27', 'CCL5', 'CCN3', 'CD14', 'CD163', 'CD209', 'CD2AP', 'CD46', 'CD55', 'CD59', 'CD69', 'CD93', 'CDH1', 'CDH17', 'CDH2', 'CDH5', 'CDH6', 'CDHR5', 'CEACAM8', 'CEBPB', 'CELA3A', 'CEP43', 'CES1', 'CGREF1', 'CHEK2', 'CHI3L1', 'CHIT1', 'CHL1', 'CHRDL2', 'CLC', 'CLEC1A', 'CLEC5A', 'CLTA', 'CLUL1', 'CNDP1', 'CNPY2', 'CNST', 'CNTN1', 'COL18A1', 'COL1A1', 'COL4A1', 'COL6A3', 'COMP', 'COMT', 'CORO1A', 'CPA1', 'CPB1', 'CR2', 'CRHR1', 'CRTAC1', 'CRX', 'CST3', 'CST6', 'CSTB', 'CTF1', 'CTSB', 'CTSD', 'CTSH', 'CTSL', 'CTSZ', 'CXCL16', 'CXCL5', 'DCN', 'DCTPP1'
# ...

# %% [markdown]
# ## Enrichment

# %%
from enrichment_proteins import *

# %%
# results_path = 'C:/Users/utente/OneDrive - Politecnico di Milano/Desktop/TESI/'
# exp_name= 'pathway_enrichment_analysis_pair'
# enr_type= 'pairs'
# fold =None
# enrich_genesets_dbs = 'KEGG_2021_Human'
# p_value_threshold = 1
# top_n_terms=None
# kegg_path = 'C:/Users/utente/OneDrive - Politecnico di Milano/Desktop/TESI/kegg_hierarchy.csv'
# save_table=True

# enriched_df_full = perform_enrichment_analysis(results_path=results_path , exp_name=exp_name, enr_type= enr_type,
#                                 fold = fold, enrich_genesets_dbs = enrich_genesets_dbs,
#                                 p_value_threshold = p_value_threshold, top_n_terms=top_n_terms,kegg_path = kegg_path, save_table=save_table)

# %%
#enriched_df_full.head()

# %% [markdown]
# ## Complete pathway dataset

# %%
enriched_df_cardio = pd.read_csv('C:/Users/utente/OneDrive - Politecnico di Milano/Desktop/TESI/pathway_enrichment_analysis_pair_unfiltered.csv')
enriched_df_cardio
# Out:
#      Unnamed: 0         Gene_set                                    Term  \
# 0             0  KEGG_2021_Human                 Cell adhesion molecules
# 1             1  KEGG_2021_Human  Cytokine-cytokine receptor interaction
# 2             2  KEGG_2021_Human     Complement and coagulation cascades
# 3             3  KEGG_2021_Human                ECM-receptor interaction
# 4             4  KEGG_2021_Human              PI3K-Akt signaling pathway
# ..          ...              ...                                     ...
# 246         246  KEGG_2021_Human                 Chemical carcinogenesis
# 247         247  KEGG_2021_Human                               Mitophagy
# 248         248  KEGG_2021_Human                               Mitophagy
# 249         249  KEGG_2021_Human           Pathways of neurodegeneration
# 250         250  KEGG_2021_Human                           RNA transport
#
#     Overlap       P-value  Adjusted P-value  Old P-value  \
# ...

# %% [markdown]
# ## Keep only Cardiometabolic Diseases (do we want to do that?)

# %%
pathways = enriched_df_cardio[(enriched_df_cardio['Subcategory'] == 'Cardiovascular disease') | (enriched_df_cardio['Subcategory'] == 'Endocrine and metabolic disease')]

# %%
pathways
# Out:
#      Unnamed: 0         Gene_set  \
# 11           11  KEGG_2021_Human
# 19           19  KEGG_2021_Human
# 30           30  KEGG_2021_Human
# 61           61  KEGG_2021_Human
# 83           83  KEGG_2021_Human
# 114         114  KEGG_2021_Human
# 115         115  KEGG_2021_Human
# 120         120  KEGG_2021_Human
# 129         129  KEGG_2021_Human
# 145         145  KEGG_2021_Human
# 146         146  KEGG_2021_Human
# 147         147  KEGG_2021_Human
# 160         160  KEGG_2021_Human
#
#                                                   Term Overlap   P-value  \
# 11              Fluid shear stress and atherosclerosis  13/139  0.000002
# 19   AGE-RAGE signaling pathway in diabetic complic...   9/100  0.000092
# 30                           Lipid and atherosclerosis  12/215  0.000634
# 61                                   Viral myocarditis    4/60  0.024102
# 83                   Non-alcoholic fatty liver disease   6/155  0.065794
# ...

# %% [markdown]
# We only have 13 pathways of which only 4 are significant at level 0.1 (too few?)

# %% [markdown]
# ## Filtering w.r.t adjusted P-value

# %%
enriched_df_filtered = enriched_df_cardio[enriched_df_cardio['Adjusted P-value'] < 0.1]
enriched_df_filtered
# Out:
#      Unnamed: 0         Gene_set                                    Term  \
# 0             0  KEGG_2021_Human                 Cell adhesion molecules
# 1             1  KEGG_2021_Human  Cytokine-cytokine receptor interaction
# 2             2  KEGG_2021_Human     Complement and coagulation cascades
# 3             3  KEGG_2021_Human                ECM-receptor interaction
# 4             4  KEGG_2021_Human              PI3K-Akt signaling pathway
# ..          ...              ...                                     ...
# 59           59  KEGG_2021_Human                  AMPK signaling pathway
# 60           60  KEGG_2021_Human         Human cytomegalovirus infection
# 61           61  KEGG_2021_Human                       Viral myocarditis
# 62           62  KEGG_2021_Human             Arachidonic acid metabolism
# 237         237  KEGG_2021_Human                     Coronavirus disease
#
#     Overlap       P-value  Adjusted P-value  Old P-value  \
# ...

# %% [markdown]
# 64 pathways, maybe a better latent space

# %%
print(list(proteins_md.get('gene_name').unique()))
# Out:
# ['A1BG', 'AAMDC', 'AARSD1', 'ABCA2', 'ABHD14B', 'ABL1', 'ABO', 'ABRAXAS2', 'ACAA1', 'ACADM', 'ACADSB', 'ACAN', 'ACE', 'ACE2', 'ACHE', 'ACOT13', 'ACOX1', 'ACP1', 'ACP5', 'ACP6', 'ACRBP', 'ACRV1', 'ACSL1', 'ACTA2', 'ACTN2', 'ACTN4', 'ACVRL1', 'ACY1', 'ACY3', 'ACYP1', 'ADA', 'ADA2', 'ADAM12', 'ADAM15', 'ADAM22', 'ADAM23', 'ADAM8', 'ADAM9', 'ADAMTS1', 'ADAMTS13', 'ADAMTS15', 'ADAMTS16', 'ADAMTS4', 'ADAMTS8', 'ADAMTSL2', 'ADAMTSL4', 'ADAMTSL5', 'ADCYAP1R1', 'ADD1', 'ADGRB3', 'ADGRD1', 'ADGRE1', 'ADGRE2', 'ADGRE5', 'ADGRF5', 'ADGRG1', 'ADGRG2', 'ADGRV1', 'ADH1B', 'ADH4', 'ADIPOQ', 'ADM', 'ADRA2A', 'AFAP1', 'AFM', 'AFP', 'AGBL2', 'AGER', 'AGR2', 'AGR3', 'AGRN', 'AGRP', 'AGT', 'AGXT', 'AHCY', 'AHNAK', 'AHNAK2', 'AHSA1', 'AHSG', 'AHSP', 'AIDA', 'AIF1', 'AIF1L', 'AIFM1', 'AK1', 'AK2', 'AKAP12', 'AKR1B1', 'AKR1B10', 'AKR1C4', 'AKR7L', 'AKT1S1', 'AKT2', 'AKT3', 'ALCAM', 'ALDH1A1', 'ALDH2', 'ALDH3A1', 'ALDH5A1', 'ALMS1', 'ALPI', 'ALPP', 'AMBN', 'AMBP', 'AMDHD2', 'AMFR', 'AMIGO1', 'AMIGO2', 'AMN',
# ...

# %%
# results_path = 'C:/Users/utente/OneDrive - Politecnico di Milano/Desktop/TESI/'
# exp_name= 'pathway_enrichment_analysis_full'
# enr_type= 'pairs'
# fold =None
# enrich_genesets_dbs = 'KEGG_2021_Human'
# p_value_threshold = 1
# top_n_terms=None
# kegg_path = 'C:/Users/utente/OneDrive - Politecnico di Milano/Desktop/TESI/kegg_hierarchy.csv'
# save_table=True

# enriched_df_full = perform_enrichment_analysis(results_path=results_path , exp_name=exp_name, enr_type= enr_type,
#                                 fold = fold, enrich_genesets_dbs = enrich_genesets_dbs,
#                                 p_value_threshold = p_value_threshold, top_n_terms=top_n_terms,kegg_path = kegg_path, save_table=save_table)
# Out:
# Unfiltered results saved to: C:/Users/utente/OneDrive - Politecnico di Milano/Desktop/TESI/pathway_enrichment_analysis_full_unfiltered.csv

# %%
enriched_df_full = pd.read_csv('C:/Users/utente/OneDrive - Politecnico di Milano/Desktop/TESI/pathway_enrichment_analysis_full_unfiltered.csv',index_col=0)

# %%
enriched_df_full
# Out:
#             Gene_set                                               Term  \
# 0    KEGG_2021_Human             Cytokine-cytokine receptor interaction
# 1    KEGG_2021_Human  Viral protein interaction with cytokine and cy...
# 2    KEGG_2021_Human                         PI3K-Akt signaling pathway
# 3    KEGG_2021_Human                         JAK-STAT signaling pathway
# 4    KEGG_2021_Human                                 Pathways in cancer
# ..               ...                                                ...
# 320  KEGG_2021_Human                     Glycosphingolipid biosynthesis
# 321  KEGG_2021_Human                     Glycosphingolipid biosynthesis
# 322  KEGG_2021_Human                     Glycosphingolipid biosynthesis
# 323  KEGG_2021_Human       Metabolism of xenobiotics by cytochrome P450
# 324  KEGG_2021_Human                                      RNA transport
#
#      Overlap       P-value  Adjusted P-value  Old P-value  \
# ...

# %%
pathways_cardio = enriched_df_full[(enriched_df_full['Subcategory'] == 'Cardiovascular disease') | (enriched_df_full['Subcategory'] == 'Endocrine and metabolic disease')]

# %%
pathways_cardio
# Out:
#             Gene_set                                               Term  \
# 10   KEGG_2021_Human                          Lipid and atherosclerosis
# 21   KEGG_2021_Human  AGE-RAGE signaling pathway in diabetic complic...
# 31   KEGG_2021_Human             Fluid shear stress and atherosclerosis
# 57   KEGG_2021_Human                           Type I diabetes mellitus
# 69   KEGG_2021_Human                                  Viral myocarditis
# 88   KEGG_2021_Human                  Non-alcoholic fatty liver disease
# 91   KEGG_2021_Human                        Hypertrophic cardiomyopathy
# 132  KEGG_2021_Human                             Dilated cardiomyopathy
# 133  KEGG_2021_Human    Arrhythmogenic right ventricular cardiomyopathy
# 151  KEGG_2021_Human                            Diabetic cardiomyopathy
# 152  KEGG_2021_Human                                 Insulin resistance
# 209  KEGG_2021_Human                                   Cushing syndrome
# ...

# %%
enriched_df_full_filtered = enriched_df_full[enriched_df_full['Adjusted P-value'] < 0.1]
enriched_df_full_filtered
# Out:
#             Gene_set                                               Term  \
# 0    KEGG_2021_Human             Cytokine-cytokine receptor interaction
# 1    KEGG_2021_Human  Viral protein interaction with cytokine and cy...
# 2    KEGG_2021_Human                         PI3K-Akt signaling pathway
# 3    KEGG_2021_Human                         JAK-STAT signaling pathway
# 4    KEGG_2021_Human                                 Pathways in cancer
# ..               ...                                                ...
# 310  KEGG_2021_Human                      Pathways of neurodegeneration
# 311  KEGG_2021_Human                            Chemical carcinogenesis
# 312  KEGG_2021_Human                            Chemical carcinogenesis
# 313  KEGG_2021_Human                            Chemical carcinogenesis
# 314  KEGG_2021_Human                                    Drug metabolism
#
#      Overlap       P-value  Adjusted P-value  Old P-value  \
# ...
